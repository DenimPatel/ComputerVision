# %% [markdown]
# ## TEMPLATE MATCHING

# %% [markdown]
# # LOAD/DISPLAY IMAGE

# %%
import cv2
import numpy as np
import matplotlib.image as mpimg
from matplotlib import pyplot as plt
# %matplotlib inline

image_color = cv2.imread('Find_Truck_color.jpg')
# image_color = mpimg.imread('Truck_detection.jpg') # import image as RGB instead of BGR 


cv2.imshow('Find Truck Template Matching', image_color)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
height, width = image_color.shape[:2]
print(height)
print(width)
# Out:
# 628
# 1194

# %%
plt.imshow(image_color)

# %% [markdown]
# ## CONVERT TO GREYSCALE

# %%
image_gray = cv2.cvtColor(image_color, cv2.COLOR_BGR2GRAY)
plt.imshow(image_gray, cmap = 'gray')

# %%
image_gray.shape
# Out:
# (628, 1194)

# %%
# Load Template image
template = cv2.imread('Truck_template.jpg',0)

cv2.imshow('Truck Template', template)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
template.shape
# see that the template is of same size as object present in an image
# Out:
# (209, 200)

# %%
w, h = template.shape[::-1]
print(w)
print(h)
# Out:
# 200
# 209

# %% [markdown]
# # PERFORM TEMPLATE MATCHING

# %%
# Perform template matching!
result = cv2.matchTemplate(image_gray, template, cv2.TM_CCOEFF_NORMED)
result.shape
# Out:
# (420, 995)

# %%
cv2.imshow('Matching Results', result)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
plt.imshow(result)
# bright dot is out object detected!!

# %%
##  where is the object in term of pixel??

# Find the indices of the object to be find 
min_val, max_val, min_loc, max_loc = cv2.minMaxLoc(result)

# %%
max_loc
# Out:
# (616, 142)

# %%
# Draw a box around the object (if found)
top_left = max_loc
bottom_right = (top_left[0] + w, top_left[1] + h)
cv2.rectangle(image_color, top_left, bottom_right, (0,0,255), 5);

# %%
cv2.imshow('Truck Located!', image_color)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
plt.imshow(image_color)
