# %% [markdown]
# ## HARRIS CORNER DETECTION

# %% [markdown]
# # LOAD/DISPLAY IMAGE

# %%
import cv2
import numpy as np
import matplotlib.image as mpimg
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
image_color = cv2.imread('chessboard.jpg')
cv2.imshow('Chessboard', image_color)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# ## CONVERT TO GREYSCALE/APPLY HARRIS CORNER

# %%
image_gray = cv2.cvtColor(image_color, cv2.COLOR_BGR2GRAY)

corners = cv2.cornerHarris(image_gray, 5, 3, 0.1)
plt.imshow(corners, cmap = 'gray')
plt.show()

# %%
corners_dilate = cv2.dilate(corners, np.ones((8,8),np.uint8), iterations = 1)
plt.imshow(corners_dilate, cmap = 'gray')

# %%
image_color[corners_dilate > 0.01 * corners_dilate.max() ] = [0, 255, 0]

cv2.imshow('Image with Corners', image_color)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
plt.imshow(image_color)

# %% [markdown]
# # CORNERS OF A building!

# %%
image_color = cv2.imread('antilia.jpg')
cv2.imshow("someone's house", image_color)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
plt.imshow(image_color)

# %% [markdown]
# ## CONVERT TO GREYSCALE

# %%
image_gray = cv2.cvtColor(image_color, cv2.COLOR_BGR2GRAY)
plt.imshow(image_gray, cmap = 'gray')

# %%
image_gray.shape
# Out:
# (360, 240)

# %% [markdown]
# # PERFORM HARRIS CORNER DETECTION

# %%
corners = cv2.cornerHarris(image_gray, 10, 3, 0.1)
corners_dilate = cv2.dilate(corners, np.ones((8,8),np.uint8), iterations = 1)

# %%
plt.imshow(corners, cmap = 'gray')
plt.show()

# %%
plt.imshow(corners_dilate, cmap = 'gray')

# %%
corners_dilate
# Out:
# array([[  1.25175499e-12,   2.28163083e-12,   2.89181049e-12, ...,
#           3.38908519e-11,   3.38908519e-11,   3.38908519e-11],
#        [  2.02748734e-12,   4.33447072e-12,   4.80748340e-12, ...,
#           3.38908519e-11,   3.38908519e-11,   3.38908519e-11],
#        [  2.02748734e-12,   4.33447072e-12,   4.80748340e-12, ...,
#           3.38908519e-11,   3.38908519e-11,   3.38908519e-11],
#        ...,
#        [ -1.79758819e-04,  -1.79758819e-04,  -1.79758819e-04, ...,
#           7.68237223e-04,   7.64427357e-04,   6.40759419e-04],
#        [ -1.79758819e-04,  -1.79758819e-04,  -1.79758819e-04, ...,
#           7.23662262e-04,   7.18576484e-04,   6.40759419e-04],
#        [ -1.79758819e-04,  -1.79758819e-04,  -1.79758819e-04, ...,
#           5.28596342e-04,   5.28596342e-04,   5.28596342e-04]], dtype=float32)

# %%
corners_dilate.shape
# Out:
# (360, 240)

# %%
#np.set_printoptions(threshold=np.nan)
#corners_dilate

# %%
corners_dilate.max()
# Out:
# 0.0097084334

# %%
# If pixel value is greater than a threshold, return true and mark it as green
Image_color_corners = image_color.copy()
Image_color_corners[corners_dilate > 0.1 * corners_dilate.max() ] = [0, 255, 0]

cv2.imshow('Image with Corners', Image_color_corners)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
plt.imshow(Image_color_corners)

# %% [markdown]
# ## you can set the corner dilate value threshold as per your need to get best candidates
