# %% [markdown]
# ## To get the webcam feed

# %%
import cv2
import matplotlib.pyplot as plt

def show_webcam(mirror=False):
    cam = cv2.VideoCapture(0)
    while True:
        ret_val, img = cam.read()
        if mirror: 
            img = cv2.flip(img, 1)
        cv2.imshow('my webcam', img)
        if cv2.waitKey(1) == 27:
            plt.imshow(img)#just to show the resut at the end
            break  # esc to quit
    cv2.destroyAllWindows()

# %%
 show_webcam(mirror=True)

# %%
# %matplotlib notebook

import cv2
import matplotlib.pyplot as plt
import signal

# %%
vc = cv2.VideoCapture(0)

plt.ion()

if vc.isOpened(): # try to get the first frame
    is_capturing, frame = vc.read()
    frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)    # makes the blues image look real colored
    webcam_preview = plt.imshow(frame)    
else:
    is_capturing = False

is_interrupted = False
while is_capturing:
    is_capturing, frame = vc.read()
    frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)    # makes the blues image look real colored
#     cv2.imshow("hello",frame)
    plt.pause(1)
    webcam_preview.set_data(frame)
    plt.draw()

    try:    # Avoids a NotImplementedError caused by `plt.pause`
        plt.pause(0.05)
    except Exception:
        pass
    if is_interrupted:
        vc.release()
        break
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-2d000f2aa78b> in <module>
#      15     frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)    # makes the blues image look real colored
#      16 #     cv2.imshow("hello",frame)
# ---> 17     plt.pause(1)
#      18     webcam_preview.set_data(frame)
#      19     plt.draw()
#
# ~/anaconda3/envs/ana41py35/lib/python3.6/site-packages/matplotlib/pyplot.py in pause(interval)
#     295         canvas.start_event_loop(interval)
#     296     else:
# --> 297         time.sleep(interval)
#     298
#     299
#
# KeyboardInterrupt:
