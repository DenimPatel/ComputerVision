# %% [markdown]
# ## PERFORM REGION OF INTEREST (ROI) SELECTION

# %% [markdown]
# # LOAD/DISPLAY IMAGE

# %%
import cv2
import numpy as np
import matplotlib.image as mpimg
from matplotlib import pyplot as plt
# %matplotlib inline

image_color = cv2.imread('road.jpg')
# image_color = mpimg.imread('image_lane_c.jpg') # import image as RGB instead of BGR 

cv2.imshow('Original Image', image_color)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
height, width = image_color.shape[:2]
print(height)
print(width)
# Out:
# 300
# 600

# %%
plt.imshow(image_color)

# %%
image_color.shape
# Out:
# (300, 600, 3)

# %% [markdown]
# ## CONVERT TO GREYSCALE

# %%
image_gray = cv2.cvtColor(image_color, cv2.COLOR_BGR2GRAY)
plt.imshow(image_gray, cmap = 'gray')

# %%
image_gray.shape
# Out:
# (300, 600)

# %% [markdown]
# # PERFORM REGION OF INTEREST MASKING

# %%
# Select points of the region of interest (ROI)
ROI = np.array([[(0, height),(0, height-100),(250, 100), (350, 100),(width, height-100), (width, height)]], dtype=np.int32)    

# you can even decide any number of points to mark region of interest
# ROI = np.array([[(0, height),(250, 100), (350, 100), (width, height)]], dtype=np.int32)    


# define a blank image with all zeros (ie: black) 
blank = np.zeros_like(image_gray)

# %%
blank.shape
# Out:
# (300, 600)

# %%
# Fill the Region of interest with white color (ie: 255)!
mask = cv2.fillPoly(blank, ROI, 255)
    
# Perform bitwise AND operation to select only the region of interest
masked_image = cv2.bitwise_and(image_gray, mask)

# %%
masked_image.shape
# Out:
# (300, 600)

# %%
plt.imshow(masked_image, cmap = 'gray')
